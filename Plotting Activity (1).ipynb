# %%
using Plots

# %%
plot(["Bookstore", "Bookstore website", "online bookstore", "off campus bookstore", "rented textbooks","purcashed ebooks","no text books"], [576, 48, 240, 168, 36, 12, 72], seriestype = :bar, title = "Where books purchased", xlabel = "where boooks bought", ylabel = "how many people bought", label = "books bought", lw = 3)

# %%
X = ["Security", "Maintence", "Flight operations", "Hazardous materials", "other"];
Y = [0.43, 0.39, 0.06, 0.03, 0.09]
 
P = pie(X,Y)

# %%
plot(["Security", "Maintence", "Flight operations", "Hazardous materials", "other"], [0.43, 0.39, 0.06, 0.03, 0.09], seriestype = :pie, title = "type of violation", xlabel = "where boooks bought", ylabel = "how many people bought", label = "violations", lw = 3)
