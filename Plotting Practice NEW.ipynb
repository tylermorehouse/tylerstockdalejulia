# %%
using Plots
 # These are the plotting data
plot([6,10,15,20,26], [4,13,18,23,27], seriestype = :scatter, title = "Ratio of Heads to Tails", xlabel = "Heads", ylabel = "Tails", label = "Coin Flip", lw = 3)
